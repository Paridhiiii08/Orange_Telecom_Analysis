# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filepath='Orange_Telecom_Churn_Data.csv'

# %%
data =pd.read_csv(filepath)

# %%
data.head()
# Out:
#   state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 0    KS             128        415     382-4657        no             yes
# 1    OH             107        415     371-7191        no             yes
# 2    NJ             137        415     358-1921        no              no
# 3    OH              84        408     375-9999       yes              no
# 4    OK              75        415     330-6626       yes              no
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0             45.07  ...               99             16.78
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          5000 non-null   object
#  1   account_length                 5000 non-null   int64
#  2   area_code                      5000 non-null   int64
#  3   phone_number                   5000 non-null   object
#  4   intl_plan                      5000 non-null   object
#  5   voice_mail_plan                5000 non-null   object
#  6   number_vmail_messages          5000 non-null   int64
#  7   total_day_minutes              5000 non-null   float64
#  8   total_day_calls                5000 non-null   int64
#  9   total_day_charge               5000 non-null   float64
#  10  total_eve_minutes              5000 non-null   float64
#  11  total_eve_calls                5000 non-null   int64
# ...

# %%
data.describe()
# Out:
#        account_length    area_code  number_vmail_messages  total_day_minutes  \
# count      5000.00000  5000.000000            5000.000000        5000.000000
# mean        100.25860   436.911400               7.755200         180.288900
# std          39.69456    42.209182              13.546393          53.894699
# min           1.00000   408.000000               0.000000           0.000000
# 25%          73.00000   408.000000               0.000000         143.700000
# 50%         100.00000   415.000000               0.000000         180.100000
# 75%         127.00000   415.000000              17.000000         216.200000
# max         243.00000   510.000000              52.000000         351.500000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      5000.000000       5000.000000        5000.000000      5000.000000
# mean        100.029400         30.649668         200.636560       100.191000
# ...

# %%
data= data.drop(columns=['phone_number'])

# %%
data['intl_plan']=data['intl_plan'].map({'yes':1, 'no':0})

data['voice_mail_plan'] = data['voice_mail_plan'].map({'yes': 1, 'no': 0})

# %%
data= data.drop_duplicates()

# %%
data.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# intl_plan                        0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churned                          0
# dtype: int64

# %%
data['intl_plan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='churned', data=data)
plt.title('Churn Rate')
plt.xticks([0, 1], ['Not Churned', 'Churned'])
plt.ylabel('Number of Customers')
plt.show()

# %%
# Churn by International Plan
sns.barplot(x='intl_plan', y='churned', data=data, estimator=lambda x: x.mean())
plt.title('Churn Rate by International Plan')
plt.xticks([0, 1], ['No Intl Plan', 'Intl Plan'])
plt.show()

# %%
sns.barplot(x='voice_mail_plan', y='churned', data=data, estimator=lambda x: x.mean())
plt.title('Churn Rate by Voicemail Plan')
plt.xticks([0, 1], ['No Voicemail Plan', 'Voicemail Plan'])
plt.show()

# %%
customer_service_churn = data.groupby('number_customer_service_calls')['churned'].mean().reset_index()
sns.lineplot(x='number_customer_service_calls', y='churned', data=customer_service_churn, marker='o')
plt.title('Churn Rate by Customer Service Calls')
plt.xlabel('Number of Customer Service Calls')
plt.ylabel('Churn Rate')
plt.show()

# %%
usage_columns = ['total_day_minutes', 'total_eve_minutes', 'total_night_minutes', 'total_intl_minutes']
plt.figure(figsize=(12, 8))
for i, column in enumerate(usage_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(data[column], kde=True)
    plt.title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %%
print(data.dtypes)
# Out:
# state                             object
# account_length                     int64
# area_code                          int64
# intl_plan                         object
# voice_mail_plan                   object
# number_vmail_messages              int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_intl_minutes               float64
# total_intl_calls                   int64
# total_intl_charge                float64
# number_customer_service_calls      int64
# churned                             bool
# dtype: object

# %%
numeric_data = data.select_dtypes(include=['number'])

# %%
print(numeric_data.columns)
# Out:
# Index(['account_length', 'area_code', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
